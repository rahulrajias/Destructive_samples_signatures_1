# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import os
import re
import matplotlib as mpl
mpl.get_backend()
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import spectroradiometer 12 march 2018 folder
# *this code reads each spectroradiometer file, converts the data into reflectance, save the reflectance values in dataframe and all the dataframes (belongs to different folders) are saved in a dictionary called all_data_dict*

# %%
folder_folders = os.walk("/home/alone/Documents/coding/Destructive/data_12_mar_2018")
folder_list = []
folder_names = []
for root, dirs, files in os.walk("/home/alone/Documents/coding/Destructive/data_12_mar_2018", topdown=False):
    for name in dirs:
        if not os.path.isfile(os.path.join(root, name)):
            folder_list.append(os.path.join(root, name))
            folder_names.append(name)
            print (os.path.join(root, name))
# print(folder_list)
print(folder_names)

all_data_dict = {}
for k in range(len(folder_list)):
    all_data = pd.DataFrame(columns=["Lambda"])
    file_list1 = os.listdir(folder_list[k])
    file_list=sorted(file_list1)
    for j in range(len(file_list)):
        raw_data = open(os.path.join(folder_list[k],file_list[j]), "r")
        f = raw_data.readlines()
        usable_part = f[78:459]
        usable_part = [i.split("  ") for i in usable_part]
        data = pd.DataFrame(usable_part)
        for index,rows in data.iterrows():
            re_pattern = r"(.*)\n"
            data.set_value(index, 2, re.search(re_pattern, rows[2]).group(1))
        data.columns=["Lambda","target","ref"]
        data.ref=pd.to_numeric(data.ref)
        data.target=pd.to_numeric(data.target)
        Reflectance=(data.target)/(data.ref)
        data=data.drop("ref",1)
        data=data.drop("target",1)
        if all_data["Lambda"].empty:
            all_data["Lambda"] = data["Lambda"]
        all_data["R"+str(j+1)]=Reflectance
    all_data_dict [folder_names[k]] = all_data
    
print("all_data_dict is a dictionary where key is folder name and stored values are dataFrame consists of reflectance values of that folder ")
# Out:
# /home/alone/Documents/coding/Destructive/data_12_mar_2018/D2_R2_R3_12_mar_2018
# /home/alone/Documents/coding/Destructive/data_12_mar_2018/D3_R1_destructive_12_mar_2018
# /home/alone/Documents/coding/Destructive/data_12_mar_2018/D2R1_destructive_12_mar_2018
# ['D2_R2_R3_12_mar_2018', 'D3_R1_destructive_12_mar_2018', 'D2R1_destructive_12_mar_2018']
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# all_data_dict is a dictionary where key is folder name and stored values are dataFrame consists of reflectance values of that folder

# %%
D3R1=all_data_dict['D3_R1_destructive_12_mar_2018']
D3R1.head()
D3R1.set_index('Lambda')
# D3R1.head()
D3R1_transposed = D3R1.T
D3R1_transposed
D3R1_transposed.columns=D3R1_transposed.iloc[0,:] 
D3R1_transposed.head()
D3R1_1=D3R1_transposed.iloc[1:,:]
D3R1_1.head()
# Out:
# Lambda     400.35     402.00     403.64     405.29     406.93     408.58  \
# R1      0.0736641  0.0732575   0.075584  0.0753482  0.0767085  0.0794552
# R2      0.0974555  0.0979137   0.098832  0.0993035    0.10271   0.103197
# R3      0.0947837  0.0967283  0.0957996  0.0978261  0.0985256  0.0987514
# R4      0.0592214  0.0585318  0.0612714  0.0591704  0.0618249  0.0615425
# R5      0.0580347   0.058201  0.0603304  0.0609397  0.0629423  0.0631273
#
# Lambda     410.22     411.86     413.51     415.15    ...       985.24  \
# R1      0.0831188  0.0851007  0.0899788   0.094042    ...     0.592317
# R2       0.106197    0.10818   0.112385   0.117222    ...     0.605948
# R3       0.101048   0.101408    0.10374   0.104971    ...     0.541512
# R4       0.063315  0.0637768  0.0642822  0.0667105    ...     0.510922
19.4918839154,19.4918839154,19.4918839154,
24.7245508982,24.7245508982,24.7245508982]
Water_D2R1_12_Mar_2018=[66.0,66.0,66.0,
63.2,63.2,63.2,
63.7,63.7,63.7,
63.8,63.8,63.8,
63.9,63.9,63.9,
66.6,66.6,66.6,
66.5,66.5,66.5,
61.7,61.7,61.7,
65.0,65.0,65.0,
59.4,59.4,59.4,
66.8,66.8,66.8,
71.9,71.9,71.9]

# %%
D3R1_1["DAS"]=DAS_D3R1_12_Mar_2018
D3R1_1["Nitrogen"]=Nitrogen_D3R1_12_Mar_2018
D3R1_1["Carbon"]=Carbon_D3R1_12_Mar_2018
D3R1_1["CNRatio"]=CNRatio_D3R1_12_Mar_2018
D3R1_1["Hydrogen"]=Hydrogen_D3R1_12_Mar_2018
D3R1_1["Water"]=Water_D3R1_12_Mar_2018
D3R1_1.head()
D3R1_1.to_csv("D3R1_12_Mar_2018.csv")
# Out:
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
D2R1_1["DAS"]=DAS_D2R1_12_Mar_2018
D2R1_1["Nitrogen"]=Nitrogen_D2R1_12_Mar_2018
D2R1_1["Carbon"]=Carbon_D2R1_12_Mar_2018
D2R1_1["CNRatio"]=CNRatio_D2R1_12_Mar_2018
D2R1_1["Hydrogen"]=Hydrogen_D2R1_12_Mar_2018
D2R1_1["Water"]=Water_D2R1_12_Mar_2018

D2R1_1.head()
# D2R1_1.to_csv("D2R1_12_Mar_2018.csv")
# Out:
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Lambda     400.35     402.00     403.64     405.29     406.93     408.58  \
# R1       0.111981   0.113173   0.114257    0.11844   0.122068   0.125132
# R2      0.0620375   0.061622  0.0641443   0.063948  0.0654457  0.0664137
# R3      0.0929141   0.093162  0.0937108  0.0949172  0.0959348  0.0949821
# R4       0.101667   0.101553   0.102425    0.10332   0.105046   0.106749
# R5      0.0864103  0.0844684   0.086789  0.0867205  0.0885605  0.0908745
#
# Lambda     410.22     411.86     413.51     415.15  ...     994.18    995.67  \
# R1       0.130546   0.134265   0.139831   0.146528  ...   0.662275  0.673267
# R2      0.0689195  0.0711454  0.0732496  0.0765006  ...     0.5319  0.536068
# R3      0.0964462  0.0973048  0.0975681  0.0989604  ...   0.596394  0.603253
# R4       0.109716   0.112055   0.114716   0.118261  ...   0.606242  0.611035
# R5      0.0919837  0.0953318  0.0971631   0.102174  ...   0.547145   0.55109
#
# Lambda    997.16    998.65  DAS Nitrogen   Carbon    CNRatio Hydrogen Water
# R1      0.655444  0.678358  122   1.9020  38.6365  20.313617    5.454  66.0
# R2      0.532235   0.54403  122   1.9020  38.6365  20.313617    5.454  66.0
# R3      0.593123  0.606716  122   1.9020  38.6365  20.313617    5.454  66.0
# R4      0.610264  0.622669  122   1.7165  39.8930  23.240897    5.627  63.2
# R5      0.549237  0.550933  122   1.7165  39.8930  23.240897    5.627  63.2
#
# [5 rows x 387 columns]

# %%
folder_folders = os.walk("/home/alone/Documents/coding/Destructive/data_19_22_feb_2018")
folder_list = []
folder_names = []
for root, dirs, files in os.walk("/home/alone/Documents/coding/Destructive/data_19_22_feb_2018", topdown=False):
    for name in dirs:
        if not os.path.isfile(os.path.join(root, name)):
            folder_list.append(os.path.join(root, name))
            folder_names.append(name)
            print (os.path.join(root, name))
# print(folder_list)
print(folder_names)

all_data_dict = {}
for k in range(len(folder_list)):
    all_data = pd.DataFrame(columns=["Lambda"])
    file_list2 = os.listdir(folder_list[k])
    file_list=sorted(file_list2)
    for j in range(len(file_list)):
        raw_data = open(os.path.join(folder_list[k],file_list[j]), "r")
        f = raw_data.readlines()
        usable_part = f[78:459]
        usable_part = [i.split("  ") for i in usable_part]
        data = pd.DataFrame(usable_part)
        for index,rows in data.iterrows():
            re_pattern = r"(.*)\n"
            data.set_value(index, 2, re.search(re_pattern, rows[2]).group(1))
        data.columns=["Lambda","target","ref"]
        data.ref=pd.to_numeric(data.ref)
        data.target=pd.to_numeric(data.target)
        Reflectance=(data.target)/(data.ref)
        data=data.drop("ref",1)
        data=data.drop("target",1)
        if all_data["Lambda"].empty:
            all_data["Lambda"] = data["Lambda"]
        all_data["R"+str(j+1)]=Reflectance
    all_data_dict [folder_names[k]] = all_data
    
print("all_data_dict is a dictionary where key is folder name and stored values are dataFrame consists of reflectance values of that folder ")
# Out:
# /home/alone/Documents/coding/Destructive/data_19_22_feb_2018/D2R1_destructive_19_22_feb_2018
# /home/alone/Documents/coding/Destructive/data_19_22_feb_2018/D1R1_destructive_19_22_feb_2018
# /home/alone/Documents/coding/Destructive/data_19_22_feb_2018/D1_R2_R3_19_22_feb_2018
# ['D2R1_destructive_19_22_feb_2018', 'D1R1_destructive_19_22_feb_2018', 'D1_R2_R3_19_22_feb_2018']
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# all_data_dict is a dictionary where key is folder name and stored values are dataFrame consists of reflectance values of that folder

# %%
D1R1=all_data_dict['D1R1_destructive_19_22_feb_2018']
D1R1.head()
D1R1_1=D1R1.T
D1R1_1.head()
D1R1_1.columns=D1R1_1.iloc[0,:]
D1R1_1.head()
D1R1_good=D1R1_1.iloc[1:,:]
D1R1_good.head()
# Out:
# Lambda     400.35     402.00     403.64     405.29     406.93     408.58  \
# R1       0.111727    0.11104    0.11259   0.111976     0.1127   0.113385
# R2       0.114737   0.114983   0.115602   0.115359   0.116062   0.117156
# R3      0.0749863  0.0751081  0.0755422  0.0749888   0.076254   0.076076
# R4      0.0727786   0.072999  0.0737888  0.0739963  0.0738786  0.0754257
# R5       0.127786   0.127896   0.128633   0.129318   0.129562   0.131645
#
# Lambda     410.22     411.86     413.51     415.15    ...       985.24  \
# R1       0.113313    0.11476   0.114894   0.117135    ...     0.580914
# R2       0.116826    0.11712   0.118154   0.119322    ...     0.592525
# R3      0.0768105   0.076963  0.0778688  0.0781831    ...          0.5
# R4      0.0773066  0.0789014  0.0817113  0.0830782    ...     0.519601
# R5       0.133511   0.135433   0.138659   0.142194    ...     0.629642
#
# Lambda    986.73    988.22    989.71    991.20    992.69    994.18    995.67  \
# R1      0.558844  0.575036   0.56383  0.569203  0.575444  0.558114  0.580757
# R2      0.568245  0.584416  0.573404  0.576812   0.58247  0.566155  0.590031
# R3      0.478412  0.498557  0.482624  0.492754  0.492973  0.482091  0.502318
# R4      0.518301  0.513736   0.52493  0.512238  0.521879  0.516594  0.511939
# R5      0.629144  0.621566  0.632374  0.626224  0.633429  0.628066  0.615412
#
# Lambda    997.16    998.65
# R1      0.558623  0.578226
# R2      0.565053   0.58871
# R3      0.476551  0.504839
# R4      0.522693  0.510258
# R5      0.631997  0.618161
#
# [5 rows x 381 columns]

# %%
D2R1=all_data_dict['D2R1_destructive_19_22_feb_2018']
D2R1.head()
D2R1_1=D2R1.T
D2R1_1.head()
D2R1_1.columns=D2R1_1.iloc[0,:]
D2R1_1.head()
D2R1_good=D2R1_1.iloc[1:,:]
D2R1_good.head()
# Out:
# Lambda     400.35     402.00     403.64     405.29     406.93     408.58  \
# R
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# Lambda     400.35     402.00     403.64     405.29     406.93     408.58  \
# R1       0.111727    0.11104    0.11259   0.111976     0.1127   0.113385
# R2       0.114737   0.114983   0.115602   0.115359   0.116062   0.117156
# R3      0.0749863  0.0751081  0.0755422  0.0749888   0.076254   0.076076
# R4      0.0727786   0.072999  0.0737888  0.0739963  0.0738786  0.0754257
# R5       0.127786   0.127896   0.128633   0.129318   0.129562   0.131645
#
# Lambda     410.22     411.86     413.51     415.15    ...       994.18  \
# R1       0.113313    0.11476   0.114894   0.117135    ...     0.558114
# R2       0.116826    0.11712   0.118154   0.119322    ...     0.566155
# R3      0.0768105   0.076963  0.0778688  0.0781831    ...     0.482091
# R4      0.0773066  0.0789014  0.0817113  0.0830782    ...     0.516594
# R5       0.133511   0.135433   0.138659   0.142194    ...     0.628066
#
# Lambda    995.67    997.16    998.65  DAS Nitrogen  Carbon    CNRatio  \
# R1      0.580757  0.558623  0.578226  115    0.780  16.779  21.511538
# R2      0.590031  0.565053   0.58871  115    0.780  16.779  21.511538
# R3      0.502318  0.476551  0.504839  115    0.780  16.779  21.511538
# R4      0.511939  0.522693  0.510258  115    1.551  21.854  14.090264
# R5      0.615412  0.631997  0.618161  115    1.551  21.854  14.090264
#
# Lambda Hydrogen     Water
# R1        8.059  58.54962
# R2        8.059  58.54962
# R3        8.059  58.54962
# R4        3.188  66.87448
# R5        3.188  66.87448
#
# [5 rows x 387 columns]

# %%
D2R1_good['DAS']= DAS_D2R1_22_Feb_2018
D2R1_good['Nitrogen']= Nitrogen_D2R1_22_Feb_2018
D2R1_good['Carbon']= Carbon_D2R1_22_Feb_2018
D2R1_good['CNRatio']= CNRatio_D2R1_22_Feb_2018
D2R1_good['Hydrogen']=Hydrogen_D2R1_22_Feb_2018
D2R1_good['Water']=Water_D2R1_22_Feb_2018
D2R1_good.to_csv('D2R1_22_Feb_2018.csv')
D2R1_good.head()
# Out:
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/alone/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Lambda     400.35     402.00     403.64     405.29     406.93     408.58  \
# R1      0.0508136    0.05105   0.051082  0.0523094  0.0516839  0.0518281
# R2      0.0690212  0.0695752  0.0686789   0.070247  0.0694867  0.0695348
# R3      0.0607567  0.0597393  0.0604783  0.0600967  0.0609657  0.0611122
# R4      0.0548664  0.0537456  0.0557895  0.0554898  0.0574369  0.0583098
# R5      0.0683445  0.0658245  0.0672632  0.0664495  0.0667914  0.0673959
#
# Lambda     410.22     411.86     413.51     415.15  ...     994.18    995.67  \
# R1      0.0522854  0.0526625  0.0534468  0.0532655  ...   0.495726  0.496356
# R2      0.0689366  0.0697654   0.070009  0.0708869  ...   0.490028  0.495627
# R3      0.0613806  0.0620036  0.0624888  0.0631691  ...   0.499644  0.501093
# R4      0.0606191   0.063249  0.0657613  0.0704759  ...   0.597241  0.595339
# R5      0.0674119  0.0682423  0.0669959  0.0696526  ...   0.571724  0.574859
#
# Lambda    997.16    998.65  DAS Nitrogen  Carbon    CNRatio Hydrogen Water
# R1      0.499255  0.495076  103    1.190  20.723  17.414286    3.917     0
# R2      0.493294  0.485985  103    1.190  20.723  17.414286    3.917     0
# R3      0.502608  0.501136  103    1.190  20.723  17.414286    3.917     0
# R4      0.577298  0.599554  103    0.891  17.949  20.144781    6.053     0
# R5      0.552228  0.575037  103    0.891  17.949  20.144781    6.053     0
#
# [5 rows x 387 columns]

# %%
D2R1_good.head()
D2R1_good.shape
# Out:
# (36, 385)
